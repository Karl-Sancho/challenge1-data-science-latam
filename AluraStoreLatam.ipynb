# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
facturación_total_tienda1 = tienda['Precio'].sum()
facturación_total_tienda2 = tienda2['Precio'].sum()
facturación_total_tienda3 = tienda3['Precio'].sum()
facturación_total_tienda4 = tienda4['Precio'].sum()

print(f'La facturación total de la tienda 1 es: {facturación_total_tienda1}')
print(f'La facturación total de la tienda 2 es: {facturación_total_tienda2}')
print(f'La facturación total de la tienda 3 es: {facturación_total_tienda3}')
print(f'La facturación total de la tienda 4 es: {facturación_total_tienda4}')
# Out:
# La facturación total de la tienda 1 es: 1150880400.0
# La facturación total de la tienda 2 es: 1116343500.0
# La facturación total de la tienda 3 es: 1098019600.0
# La facturación total de la tienda 4 es: 1038375700.0

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_palette("pastel")

sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], y=[facturación_total_tienda1, facturación_total_tienda2, facturación_total_tienda3, facturación_total_tienda4])
plt.title('Facturación total por tienda')
plt.show()

# %% [markdown]
# # > La tienda con menor facturación total es la tienda 4 <

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()

print(ventas_por_categoria_tienda1)
print(ventas_por_categoria_tienda2)
print(ventas_por_categoria_tienda3)
print(ventas_por_categoria_tienda4)

total_productos_tienda1 = ventas_por_categoria_tienda1.sum()
total_productos_tienda2 = ventas_por_categoria_tienda2.sum()
total_productos_tienda3 = ventas_por_categoria_tienda3.sum()
total_productos_tienda4 = ventas_por_categoria_tienda4.sum()

print(f'El total de productos vendidos en la tienda 1 es: {total_productos_tienda1}')
print(f'El total de productos vendidos en la tienda 2 es: {total_productos_tienda2}')
print(f'El total de productos vendidos en la tienda 3 es: {total_productos_tienda3}')
print(f'El total de productos vendidos en la tienda 4 es: {total_productos_tienda4}')

Porcentaje_categoria_tienda1 = (ventas_por_categoria_tienda1 / total_productos_tienda1) * 100
Porcentaje_categoria_tienda2 = (ventas_por_categoria_tienda2 / total_productos_tienda2) * 100
Porcentaje_categoria_tienda3 = (ventas_por_categoria_tienda3 / total_productos_tienda3) * 100
Porcentaje_categoria_tienda4 = (ventas_por_categoria_tienda4 / total_productos_tienda4) * 100

print(Porcentaje_categoria_tienda1)
print(Porcentaje_categoria_tienda2)
print(Porcentaje_categoria_tienda3)
print(Porcentaje_categoria_tienda4)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64
# Categoría del Producto
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.pie(Porcentaje_categoria_tienda1, labels=ventas_por_categoria_tienda1.index, autopct='%1.1f%%')
plt.title('Porcentaje de ventas por categoría en la tienda 1')
plt.show()

plt.pie(Porcentaje_categoria_tienda2, labels=ventas_por_categoria_tienda2.index, autopct='%1.1f%%')
plt.title('Porcentaje de ventas por categoría en la tienda 2')
plt.show()

plt.pie(Porcentaje_categoria_tienda3, labels=ventas_por_categoria_tienda3.index, autopct='%1.1f%%')
plt.title('Porcentaje de ventas por categoría en la tienda 3')
plt.show()

plt.pie(Porcentaje_categoria_tienda4, labels=ventas_por_categoria_tienda4.index, autopct='%1.1f%%')
plt.title('Porcentaje de ventas por categoría en la tienda 4')
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificación_promedio_tienda1 = tienda['Calificación'].mean()
calificación_promedio_tienda2 = tienda2['Calificación'].mean()
calificación_promedio_tienda3 = tienda3['Calificación'].mean()
calificación_promedio_tienda4 = tienda4['Calificación'].mean()

print(f'La calificación promedio de la tienda 1 es: {calificación_promedio_tienda1}')
print(f'La calificación promedio de la tienda 2 es: {calificación_promedio_tienda2}')
print(f'La calificación promedio de la tienda 3 es: {calificación_promedio_tienda3}')
print(f'La calificación promedio de la tienda 4 es: {calificación_promedio_tienda4}')
# Out:
# La calificación promedio de la tienda 1 es: 3.976685036032217
# La calificación promedio de la tienda 2 es: 4.037303942348453
# La calificación promedio de la tienda 3 es: 4.048325561678677
# La calificación promedio de la tienda 4 es: 3.9957591178965224

# %% [markdown]
# ### En cuanto a calificación promedio la tienda con menor calificación es la tienda 1

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
porducto_mas_vendido_tienda1 = tienda['Producto'].value_counts().idxmax()
porducto_menos_vendido_tienda1 = tienda['Producto'].value_counts().idxmin()

porducto_mas_vendido_tienda2 = tienda2['Producto'].value_counts().idxmax()
porducto_menos_vendido_tienda2 = tienda2['Producto'].value_counts().idxmin()

producto_mas_vendido_tienda3 = tienda3['Producto'].value_counts().idxmax()
porducto_menos_vendido_tienda3 = tienda3['Producto'].value_counts().idxmin()

producto_mas_vendido_tienda4 = tienda4['Producto'].value_counts().idxmax()
porducto_menos_vendido_tienda4 = tienda4['Producto'].value_counts().idxmin()

print(f'El producto más vendido en la tienda 1 es: {porducto_mas_vendido_tienda1} de la categoría {tienda["Categoría del Producto"][tienda["Producto"] == porducto_mas_vendido_tienda1].values[0]}')
print(f'El producto menos vendido en la tienda 1 es: {porducto_menos_vendido_tienda1} de la categoría {tienda["Categoría del Producto"][tienda["Producto"] == porducto_menos_vendido_tienda1].values[0]}')
print(f'El producto más vendido en la tienda 2 es: {porducto_mas_vendido_tienda2} de la categoría {tienda2["Categoría del Producto"][tienda2["Producto"] == porducto_mas_vendido_tienda2].values[0]}')
print(f'El producto menos vendido en la tienda 2 es: {porducto_menos_vendido_tienda2} de la categoría {tienda2["Categoría del Producto"][tienda2["Producto"] == porducto_menos_vendido_tienda2].values[0]}')
print(f'El producto más vendido en la tienda 3 es: {producto_mas_vendido_tienda3} de la categoría {tienda3["Categoría del Producto"][tienda3["Producto"] == producto_mas_vendido_tienda3].values[0]}')
print(f'El producto menos vendido en la tienda 3 es: {porducto_menos_vendido_tienda3} de la categoría {tienda3["Categoría del Producto"][tienda3["Producto"] == porducto_menos_vendido_tienda3].values[0]}')
print(f'El producto más vendido en la tienda 4 es: {producto_mas_vendido_tienda4} de la categoría {tienda4["Categoría del Producto"][tienda4["Producto"] == producto_mas_vendido_tienda4].values[0]}')
print(f'El producto menos vendido en la tienda 4 es: {porducto_menos_vendido_tienda4} de la categoría {tienda4["Categoría del Producto"][tienda4["Producto"] == porducto_menos_vendido_tienda4].values[0]}')
# Out:
# El producto más vendido en la tienda 1 es: Microondas de la categoría Electrodomésticos
# El producto menos vendido en la tienda 1 es: Auriculares con micrófono de la categoría Electrónicos
# El producto más vendido en la tienda 2 es: Iniciando en programación de la categoría Libros
# El producto menos vendido en la tienda 2 es: Juego de mesa de la categoría Juguetes
# El producto más vendido en la tienda 3 es: Kit de bancas de la categoría Muebles
# El producto menos vendido en la tienda 3 es: Bloques de construcción de la categoría Juguetes
# El producto más vendido en la tienda 4 es: Cama box de la categoría Muebles
# El producto menos vendido en la tienda 4 es: Guitarra eléctrica de la categoría Instrumentos musicales

# %% [markdown]
# ### En cuanto al analisis de productos mas vendidos y menos vendidos la tienda 2 con su producto mas vendido "libro"

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_tienda4 = tienda4['Costo de envío'].mean()

print(f'El costo de envío promedio de la tienda 1 es: {costo_envio_tienda1}')
print(f'El costo de envío promedio de la tienda 2 es: {costo_envio_tienda2}')
print(f'El costo de envío promedio de la tienda 3 es: {costo_envio_tienda3}')
print(f'El costo de envío promedio de la tienda 4 es: {costo_envio_tienda4}')
# Out:
# El costo de envío promedio de la tienda 1 es: 26018.60958033065
# El costo de envío promedio de la tienda 2 es: 25216.235693090293
# El costo de envío promedio de la tienda 3 es: 24805.680373039424
# El costo de envío promedio de la tienda 4 es: 23459.457167090754

# %%
fig, ax = plt.subplots()
ax.scatter(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [costo_envio_tienda1, costo_envio_tienda2, costo_envio_tienda3, costo_envio_tienda4])
plt.title('Costo de envío promedio por tienda')
plt.show()
